# %% [markdown]
# # CardioMate V0.0 (Beta)\n\nThis notebook is the portfolio-friendly launcher for the deployable Gradio app. The production code lives in `app.py` and the `cardiomate/` package so the same project can be pushed directly to GitHub and Hugging Face Spaces.

# %% [markdown]
# ## Setup\n\nInstall dependencies, then set `OPENAI_API_KEY` in your environment or Hugging Face Space secrets. The app also includes a local fallback for demos without an API key.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Launch CardioMate

# %%
from app import demo\n\ndemo.launch()
